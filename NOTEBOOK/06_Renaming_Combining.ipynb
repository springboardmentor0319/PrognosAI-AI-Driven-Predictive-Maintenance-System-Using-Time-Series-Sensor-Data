# %%
import pandas as pd

df = pd.read_csv(r"../dataset/train_FD001.txt", sep=r"\s+", header=None)

# %%
df = df.iloc[:, :26]

df.columns = ['engine_id', 'cycle'] + \
             [f'op_setting_{i}' for i in range(1, 4)] + \
             [f'sensor_{i}' for i in range(1, 22)]

# %%
df = df.rename(columns={'cycle': 'time_step'})

# %%
df.columns
# Out:
# Index(['engine_id', 'time_step', 'op_setting_1', 'op_setting_2',
#        'op_setting_3', 'sensor_1', 'sensor_2', 'sensor_3', 'sensor_4',
#        'sensor_5', 'sensor_6', 'sensor_7', 'sensor_8', 'sensor_9', 'sensor_10',
#        'sensor_11', 'sensor_12', 'sensor_13', 'sensor_14', 'sensor_15',
#        'sensor_16', 'sensor_17', 'sensor_18', 'sensor_19', 'sensor_20',
#        'sensor_21'],
#       dtype='object')

# %%
df = df.rename(columns={
    'sensor_1': 'fan_speed',
    'sensor_2': 'compressor_pressure'
})

# %%
df = df.rename(index={0: 'first_row', 1: 'second_row'})

# %%
df = df.rename_axis("engine_records", axis='rows')

# %%
df = df.rename_axis("features", axis='columns')

# %%
train_df = pd.read_csv("../dataset/train_FD001.txt", sep=r"\s+", header=None)
test_df = pd.read_csv("../dataset/test_FD001.txt", sep=r"\s+", header=None)

train_df = train_df.iloc[:, :26]
test_df = test_df.iloc[:, :26]

# %%
combined_df = pd.concat([train_df, test_df], axis=0)

# %%
rul_df = pd.read_csv("../dataset/RUL_FD001.txt", header=None)
rul_df.columns = ['true_RUL']

# %%
test_max_cycle = test_df.groupby(0)[1].max().reset_index()
test_max_cycle.columns = ['engine_id', 'last_cycle']

# %%
test_max_cycle['true_RUL'] = rul_df['true_RUL']
