# %%
import pandas as pd

# %%
#creating a dataframe
#dataframes are 2D data structures that can hold data of different types (like a table in a database or an Excel spreadsheet)

data = {
    "engine_id": [1, 1, 1],
    "cycle": [1, 2, 3],
    "sensor1": [500, 505, 510]
}
df_demo = pd.DataFrame(data)
df_demo
# Out:
#    engine_id  cycle  sensor1
# 0          1      1      500
# 1          1      2      505
# 2          1      3      510

# %%
#pd.Dataframe() is a constructor.
#this constructor can take varierty of data 
#we can also specify the column names and index of the dataframe
#like here "engine_id", "cycle", "sensor1" are the column names and 0, 1, 2 are the index of the dataframe

# %%
# Series
#A Series is a single column of data.

# %%
pd.Series([1, 2, 3, 4, 5])
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
#series with index and name
pd.Series(
    [100, 95, 80],
    index=['Cycle 1', 'Cycle 2', 'Cycle 3'],
    name='Engine Health Score'
)
# Out:
# Cycle 1    100
# Cycle 2     95
# Cycle 3     80
# Name: Engine Health Score, dtype: int64

# %%
#Reading Data FileExistsError
#now we will load cmapss data using pandas
#as our cmapss dataset is not in csv it is in text format we need to give them labels inorder to make the functioning smoothly

# %%
#defining column names for our dataset
cols = ['engine_id', 'cycle',
        'op1', 'op2', 'op3'] + \
       [f'sensor{i}' for i in range(1,22)]

# %%
df = pd.read_csv("../dataset/train_FD001.txt",
                 sep=r"\s+",#done for raw seperation because the dataset sometimes has a single space spertaion and sometimes double spacce seperation
                 header=None)

df.columns = cols

# %%
df.shape
#20631 rows and 26 columns
# Out:
# (20631, 26)

# %%
df.head()
# Out:
#    engine_id  cycle     op1     op2    op3  sensor1  sensor2  sensor3  \
# 0          1      1 -0.0007 -0.0004  100.0   518.67   641.82  1589.70
# 1          1      2  0.0019 -0.0003  100.0   518.67   642.15  1591.82
# 2          1      3 -0.0043  0.0003  100.0   518.67   642.35  1587.99
# 3          1      4  0.0007  0.0000  100.0   518.67   642.35  1582.79
# 4          1      5 -0.0019 -0.0002  100.0   518.67   642.37  1582.85
#
#    sensor4  sensor5  ...  sensor12  sensor13  sensor14  sensor15  sensor16  \
# 0  1400.60    14.62  ...    521.66   2388.02   8138.62    8.4195      0.03
# 1  1403.14    14.62  ...    522.28   2388.07   8131.49    8.4318      0.03
# 2  1404.20    14.62  ...    522.42   2388.03   8133.23    8.4178      0.03
# 3  1401.87    14.62  ...    522.86   2388.08   8133.83    8.3682      0.03
# 4  1406.22    14.62  ...    522.19   2388.04   8133.80    8.4294      0.03
#
#    sensor17  sensor18  sensor19  sensor20  sensor21
# ...

# %%
df.head(10)#shows the first 10 rows of the dataframe
# Out:
#    engine_id  cycle     op1     op2    op3  sensor1  sensor2  sensor3  \
# 0          1      1 -0.0007 -0.0004  100.0   518.67   641.82  1589.70
# 1          1      2  0.0019 -0.0003  100.0   518.67   642.15  1591.82
# 2          1      3 -0.0043  0.0003  100.0   518.67   642.35  1587.99
# 3          1      4  0.0007  0.0000  100.0   518.67   642.35  1582.79
# 4          1      5 -0.0019 -0.0002  100.0   518.67   642.37  1582.85
# 5          1      6 -0.0043 -0.0001  100.0   518.67   642.10  1584.47
# 6          1      7  0.0010  0.0001  100.0   518.67   642.48  1592.32
# 7          1      8 -0.0034  0.0003  100.0   518.67   642.56  1582.96
# 8          1      9  0.0008  0.0001  100.0   518.67   642.12  1590.98
# 9          1     10 -0.0033  0.0001  100.0   518.67   641.71  1591.24
#
#    sensor4  sensor5  ...  sensor12  sensor13  sensor14  sensor15  sensor16  \
# 0  1400.60    14.62  ...    521.66   2388.02   8138.62    8.4195      0.03
# ...

# %%
df.tail()#shows the last 5 rows of the dataframe
# Out:
#        engine_id  cycle     op1     op2    op3  sensor1  sensor2  sensor3  \
# 20626        100    196 -0.0004 -0.0003  100.0   518.67   643.49  1597.98
# 20627        100    197 -0.0016 -0.0005  100.0   518.67   643.54  1604.50
# 20628        100    198  0.0004  0.0000  100.0   518.67   643.42  1602.46
# 20629        100    199 -0.0011  0.0003  100.0   518.67   643.23  1605.26
# 20630        100    200 -0.0032 -0.0005  100.0   518.67   643.85  1600.38
#
#        sensor4  sensor5  ...  sensor12  sensor13  sensor14  sensor15  \
# 20626  1428.63    14.62  ...    519.49   2388.26   8137.60    8.4956
# 20627  1433.58    14.62  ...    519.68   2388.22   8136.50    8.5139
# 20628  1428.18    14.62  ...    520.01   2388.24   8141.05    8.5646
# 20629  1426.53    14.62  ...    519.67   2388.23   8139.29    8.5389
# 20630  1432.14    14.62  ...    519.30   2388.26   8137.33    8.5036
#
#        sensor16  sensor17  sensor18  sensor19  sensor20  sensor21
# ...
