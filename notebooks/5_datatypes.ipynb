# %%
import pandas as pd

df = pd.read_csv(r"C:\Projects\PrognosAI\dataset\train_FD001.txt", sep=r"\s+", header=None)

df = df.iloc[:, :26]

df.columns = ['engine_id', 'cycle'] + \
             [f'op_setting_{i}' for i in range(1, 4)] + \
             [f'sensor_{i}' for i in range(1, 22)]

# %%
df['sensor_1'].dtype
# Out:
# dtype('float64')

# %%
df.dtypes
# Out:
# engine_id         int64
# cycle             int64
# op_setting_1    float64
# op_setting_2    float64
# op_setting_3    float64
# sensor_1        float64
# sensor_2        float64
# sensor_3        float64
# sensor_4        float64
# sensor_5        float64
# sensor_6        float64
# sensor_7        float64
# sensor_8        float64
# sensor_9        float64
# sensor_10       float64
# sensor_11       float64
# sensor_12       float64
# sensor_13       float64
# sensor_14       float64
# sensor_15       float64
# sensor_16       float64
# sensor_17         int64
# sensor_18         int64
# sensor_19       float64
# sensor_20       float64
# sensor_21       float64
# dtype: object

# %%
df['cycle'] = df['cycle'].astype('int64')

# %%
df['sensor_2'] = df['sensor_2'].astype('float64')

# %%
df['engine_id'] = df['engine_id'].astype('category')

# %%
df.index.dtype
# Out:
# dtype('int64')

# %%
df.isnull().sum()
# Out:
# engine_id       0
# cycle           0
# op_setting_1    0
# op_setting_2    0
# op_setting_3    0
# sensor_1        0
# sensor_2        0
# sensor_3        0
# sensor_4        0
# sensor_5        0
# sensor_6        0
# sensor_7        0
# sensor_8        0
# sensor_9        0
# sensor_10       0
# sensor_11       0
# sensor_12       0
# sensor_13       0
# sensor_14       0
# sensor_15       0
# sensor_16       0
# sensor_17       0
# sensor_18       0
# sensor_19       0
# sensor_20       0
# sensor_21       0
# dtype: int64

# %%
df[pd.isnull(df['sensor_5'])]
# Out:
# Empty DataFrame
# Columns: [engine_id, cycle, op_setting_1, op_setting_2, op_setting_3, sensor_1, sensor_2, sensor_3, sensor_4, sensor_5, sensor_6, sensor_7, sensor_8, sensor_9, sensor_10, sensor_11, sensor_12, sensor_13, sensor_14, sensor_15, sensor_16, sensor_17, sensor_18, sensor_19, sensor_20, sensor_21]
# Index: []
#
# [0 rows x 26 columns]

# %%
df['sensor_5'].fillna(df['sensor_5'].mean(), inplace=True)
# Out:
# C:\Users\abhij\AppData\Local\Temp\ipykernel_15504\2491426563.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['sensor_5'].fillna(df['sensor_5'].mean(), inplace=True)

# %%
df.fillna(method='ffill', inplace=True)
# Out:
# C:\Users\abhij\AppData\Local\Temp\ipykernel_15504\4002983762.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='ffill', inplace=True)

# %%
df.fillna(method='bfill', inplace=True)
# Out:
# C:\Users\abhij\AppData\Local\Temp\ipykernel_15504\4042436694.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='bfill', inplace=True)

# %%
df['health_status'] = 'Healthy'

# %%
df['health_status'].replace('Healthy', 'Normal')
# Out:
# 0        Normal
# 1        Normal
# 2        Normal
# 3        Normal
# 4        Normal
#           ...
# 20626    Normal
# 20627    Normal
# 20628    Normal
# 20629    Normal
# 20630    Normal
# Name: health_status, Length: 20631, dtype: object

# %%
df['sensor_3'].replace(-999, df['sensor_3'].mean(), inplace=True)
# Out:
# C:\Users\abhij\AppData\Local\Temp\ipykernel_15504\1159728700.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['sensor_3'].replace(-999, df['sensor_3'].mean(), inplace=True)

# %%
df.nunique()
# Out:
# engine_id         100
# cycle             362
# op_setting_1      158
# op_setting_2       13
# op_setting_3        1
# sensor_1            1
# sensor_2          310
# sensor_3         3012
# sensor_4         4051
# sensor_5            1
# sensor_6            2
# sensor_7          513
# sensor_8           53
# sensor_9         6403
# sensor_10           1
# sensor_11         159
# sensor_12         427
# sensor_13          56
# sensor_14        6078
# sensor_15        1918
# sensor_16           1
# sensor_17          13
# sensor_18           1
# sensor_19           1
# sensor_20         120
# sensor_21        4745
# health_status       1
# dtype: int64

# %%
df = df.loc[:, df.nunique() > 1]
