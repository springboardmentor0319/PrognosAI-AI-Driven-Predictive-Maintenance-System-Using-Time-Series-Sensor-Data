# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Projects\PrognosAI\dataset\train_FD001.txt", sep=r"\s+", header=None)

# %%
df.engine_id = df[0]
# Out:
# C:\Users\abhij\AppData\Local\Temp\ipykernel_21644\2209690591.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.engine_id = df[0]

# %%
df.engine_id
# Out:
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
#         ...
# 20626    100
# 20627    100
# 20628    100
# 20629    100
# 20630    100
# Name: 0, Length: 20631, dtype: int64

# %%
column_names = ['engine_id', 'cycle'] + \
               [f'op_setting_{i}' for i in range(1, 4)] + \
               [f'sensor_{i}' for i in range(1, 22)]

df.columns = column_names

# %%
df.iloc[0]
# Out:
# engine_id          1.0000
# cycle              1.0000
# op_setting_1      -0.0007
# op_setting_2      -0.0004
# op_setting_3     100.0000
# sensor_1         518.6700
# sensor_2         641.8200
# sensor_3        1589.7000
# sensor_4        1400.6000
# sensor_5          14.6200
# sensor_6          21.6100
# sensor_7         554.3600
# sensor_8        2388.0600
# sensor_9        9046.1900
# sensor_10          1.3000
# sensor_11         47.4700
# sensor_12        521.6600
# sensor_13       2388.0200
# sensor_14       8138.6200
# sensor_15          8.4195
# sensor_16          0.0300
# sensor_17        392.0000
# sensor_18       2388.0000
# sensor_19        100.0000
# sensor_20         39.0600
# sensor_21         23.4190
# Name: 0, dtype: float64

# %%
df.iloc[:,0]
# Out:
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
#         ...
# 20626    100
# 20627    100
# 20628    100
# 20629    100
# 20630    100
# Name: engine_id, Length: 20631, dtype: int64

# %%
df.iloc[:3,0]
# Out:
# 0    1
# 1    1
# 2    1
# Name: engine_id, dtype: int64

# %%
df.iloc[1:3,0]
# Out:
# 1    1
# 2    1
# Name: engine_id, dtype: int64

# %%
df.iloc[[0,1,2],0]
# Out:
# 0    1
# 1    1
# 2    1
# Name: engine_id, dtype: int64

# %%
df.iloc[-5:]
# Out:
#        engine_id  cycle  op_setting_1  op_setting_2  op_setting_3  sensor_1  \
# 20626        100    196       -0.0004       -0.0003         100.0    518.67
# 20627        100    197       -0.0016       -0.0005         100.0    518.67
# 20628        100    198        0.0004        0.0000         100.0    518.67
# 20629        100    199       -0.0011        0.0003         100.0    518.67
# 20630        100    200       -0.0032       -0.0005         100.0    518.67
#
#        sensor_2  sensor_3  sensor_4  sensor_5  ...  sensor_12  sensor_13  \
# 20626    643.49   1597.98   1428.63     14.62  ...     519.49    2388.26
# 20627    643.54   1604.50   1433.58     14.62  ...     519.68    2388.22
# 20628    643.42   1602.46   1428.18     14.62  ...     520.01    2388.24
# 20629    643.23   1605.26   1426.53     14.62  ...     519.67    2388.23
# 20630    643.85   1600.38   1432.14     14.62  ...     519.30    2388.26
#
# ...

# %%
df.loc[0, 'engine_id']
# Out:
# np.int64(1)

# %%
df.loc[:, ['engine_id', 'cycle']]
# Out:
#        engine_id  cycle
# 0              1      1
# 1              1      2
# 2              1      3
# 3              1      4
# 4              1      5
# ...          ...    ...
# 20626        100    196
# 20627        100    197
# 20628        100    198
# 20629        100    199
# 20630        100    200
#
# [20631 rows x 2 columns]

# %%
df.set_index('engine_id', inplace=True)

# %%
df.engine_id == 1
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 20626    False
# 20627    False
# 20628    False
# 20629    False
# 20630    False
# Name: 0, Length: 20631, dtype: bool

# %%
df.loc[df.engine_id == 1]
# Out:
#            cycle  op_setting_1  op_setting_2  op_setting_3  sensor_1  \
# engine_id
# 1              1       -0.0007       -0.0004         100.0    518.67
# 1              2        0.0019       -0.0003         100.0    518.67
# 1              3       -0.0043        0.0003         100.0    518.67
# 1              4        0.0007        0.0000         100.0    518.67
# 1              5       -0.0019       -0.0002         100.0    518.67
# ...          ...           ...           ...           ...       ...
# 100          196       -0.0004       -0.0003         100.0    518.67
# 100          197       -0.0016       -0.0005         100.0    518.67
# 100          198        0.0004        0.0000         100.0    518.67
# 100          199       -0.0011        0.0003         100.0    518.67
# 100          200       -0.0032       -0.0005         100.0    518.67
#
#            sensor_2  sensor_3  sensor_4  sensor_5  sensor_6  ...  sensor_12  \
# ...

# %%
df.reset_index(inplace=True)

# %%
df.columns
# Out:
# Index(['index', 'engine_id', 'cycle', 'op_setting_1', 'op_setting_2',
#        'op_setting_3', 'sensor_1', 'sensor_2', 'sensor_3', 'sensor_4',
#        'sensor_5', 'sensor_6', 'sensor_7', 'sensor_8', 'sensor_9', 'sensor_10',
#        'sensor_11', 'sensor_12', 'sensor_13', 'sensor_14', 'sensor_15',
#        'sensor_16', 'sensor_17', 'sensor_18', 'sensor_19', 'sensor_20',
#        'sensor_21'],
#       dtype='object')

# %%
df.loc[(df.engine_id == 1) & (df.cycle >= 100)]
# Out:
#      index  engine_id  cycle  op_setting_1  op_setting_2  op_setting_3  \
# 99      99          1    100       -0.0021       -0.0003         100.0
# 100    100          1    101        0.0012        0.0003         100.0
# 101    101          1    102        0.0017        0.0005         100.0
# 102    102          1    103       -0.0013        0.0001         100.0
# 103    103          1    104       -0.0001        0.0001         100.0
# ..     ...        ...    ...           ...           ...           ...
# 187    187          1    188       -0.0067        0.0003         100.0
# 188    188          1    189       -0.0006        0.0002         100.0
# 189    189          1    190       -0.0027        0.0001         100.0
# 190    190          1    191       -0.0000       -0.0004         100.0
# 191    191          1    192        0.0009       -0.0000         100.0
#
#      sensor_1  sensor_2  sensor_3  sensor_4  ...  sensor_12  sensor_13  \
# ...

# %%
df.loc[(df.engine_id == 1) | (df.cycle >= 100)]
# Out:
#        index  engine_id  cycle  op_setting_1  op_setting_2  op_setting_3  \
# 0          0          1      1       -0.0007       -0.0004         100.0
# 1          1          1      2        0.0019       -0.0003         100.0
# 2          2          1      3       -0.0043        0.0003         100.0
# 3          3          1      4        0.0007        0.0000         100.0
# 4          4          1      5       -0.0019       -0.0002         100.0
# ...      ...        ...    ...           ...           ...           ...
# 20626  20626        100    196       -0.0004       -0.0003         100.0
# 20627  20627        100    197       -0.0016       -0.0005         100.0
# 20628  20628        100    198        0.0004        0.0000         100.0
# 20629  20629        100    199       -0.0011        0.0003         100.0
# 20630  20630        100    200       -0.0032       -0.0005         100.0
#
#        sensor_1  sensor_2  sensor_3  sensor_4  ...  sensor_12  sensor_13  \
# ...

# %%
df.loc[df.engine_id.isin([1, 2, 3])]
# Out:
#      index  engine_id  cycle  op_setting_1  op_setting_2  op_setting_3  \
# 0        0          1      1       -0.0007       -0.0004         100.0
# 1        1          1      2        0.0019       -0.0003         100.0
# 2        2          1      3       -0.0043        0.0003         100.0
# 3        3          1      4        0.0007        0.0000         100.0
# 4        4          1      5       -0.0019       -0.0002         100.0
# ..     ...        ...    ...           ...           ...           ...
# 653    653          3    175       -0.0030        0.0004         100.0
# 654    654          3    176       -0.0008        0.0002         100.0
# 655    655          3    177       -0.0041       -0.0002         100.0
# 656    656          3    178       -0.0010        0.0001         100.0
# 657    657          3    179        0.0012        0.0000         100.0
#
#      sensor_1  sensor_2  sensor_3  sensor_4  ...  sensor_12  sensor_13  \
# ...

# %%
df.loc[df.cycle.notnull()]
# Out:
#        index  engine_id  cycle  op_setting_1  op_setting_2  op_setting_3  \
# 0          0          1      1       -0.0007       -0.0004         100.0
# 1          1          1      2        0.0019       -0.0003         100.0
# 2          2          1      3       -0.0043        0.0003         100.0
# 3          3          1      4        0.0007        0.0000         100.0
# 4          4          1      5       -0.0019       -0.0002         100.0
# ...      ...        ...    ...           ...           ...           ...
# 20626  20626        100    196       -0.0004       -0.0003         100.0
# 20627  20627        100    197       -0.0016       -0.0005         100.0
# 20628  20628        100    198        0.0004        0.0000         100.0
# 20629  20629        100    199       -0.0011        0.0003         100.0
# 20630  20630        100    200       -0.0032       -0.0005         100.0
#
#        sensor_1  sensor_2  sensor_3  sensor_4  ...  sensor_12  sensor_13  \
# ...
